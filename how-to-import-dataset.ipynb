# %% [markdown]
# <a href="https://colab.research.google.com/github/Saxenalovish17/datasets/blob/main/how-to-import-dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#method 1 using colab directly (for current runtime only)
df = pd.read_csv('Patient_Profile.csv')

df.head()
# Out:
#    Patient_ID  Online_Follower  LinkedIn_Shared  Twitter_Shared  \
# 0      516956                0                0               0
# 1      507733                0                0               0
# 2      508307                0                0               0
# 3      512612                0                0               0
# 4      521075                0                0               0
#
#    Facebook_Shared  Income  Education_Score   Age First_Interaction City_Type  \
# 0                0     1.0             90.0  39.0         18-Jun-03       NaN
# 1                0     1.0              NaN  40.0         20-Jul-03         H
# 2                0     3.0             87.0  46.0         02-Nov-02         D
# 3                0     1.0             75.0  47.0         02-Nov-02         D
# 4                0     3.0              NaN  80.0         24-Nov-02         H
#
#    Employer_Category
# 0  Software Industry
# 1  Software Industry
# 2               BFSI
# ...

# %%
#method 2 using github raw file (will not dissappear when runtime gets dissconnected)

df = pd.read_csv('https://raw.githubusercontent.com/Saxenalovish17/datasets/refs/heads/main/Patient_Profile.csv')

df.head()
# Out:
#    Patient_ID  Online_Follower  LinkedIn_Shared  Twitter_Shared  \
# 0      516956                0                0               0
# 1      507733                0                0               0
# 2      508307                0                0               0
# 3      512612                0                0               0
# 4      521075                0                0               0
#
#    Facebook_Shared  Income  Education_Score   Age First_Interaction City_Type  \
# 0                0     1.0             90.0  39.0         18-Jun-03       NaN
# 1                0     1.0              NaN  40.0         20-Jul-03         H
# 2                0     3.0             87.0  46.0         02-Nov-02         D
# 3                0     1.0             75.0  47.0         02-Nov-02         D
# 4                0     3.0              NaN  80.0         24-Nov-02         H
#
#    Employer_Category
# 0  Software Industry
# 1  Software Industry
# 2               BFSI
# ...

# %%
#method 3 using google drive (permanent)

from google.colab import drive
drive.mount('/content/drive')

df = pd.read_csv('/content/drive/MyDrive/datasets/Patient_Profile.csv')

df.head()
# Out:
# Mounted at /content/drive
#    Patient_ID  Online_Follower  LinkedIn_Shared  Twitter_Shared  \
# 0      516956                0                0               0
# 1      507733                0                0               0
# 2      508307                0                0               0
# 3      512612                0                0               0
# 4      521075                0                0               0
#
#    Facebook_Shared  Income  Education_Score   Age First_Interaction City_Type  \
# 0                0     1.0             90.0  39.0         18-Jun-03       NaN
# 1                0     1.0              NaN  40.0         20-Jul-03         H
# 2                0     3.0             87.0  46.0         02-Nov-02         D
# 3                0     1.0             75.0  47.0         02-Nov-02         D
# 4                0     3.0              NaN  80.0         24-Nov-02         H
#
#    Employer_Category
# 0  Software Industry
# 1  Software Industry
# ...

# %%
#using kaggle
import kagglehub

# Download latest version
path = kagglehub.dataset_download("lovishai/paitent")

print("Path to dataset files:", path)

dfk = pd.read_csv('/root/.cache/kagglehub/datasets/lovishai/paitent/versions/1/Patient_Profile.csv')
dfk.head()
# Out:
# Path to dataset files: /kaggle/input/paitent
#    Patient_ID  Online_Follower  LinkedIn_Shared  Twitter_Shared  \
# 0      516956                0                0               0
# 1      507733                0                0               0
# 2      508307                0                0               0
# 3      512612                0                0               0
# 4      521075                0                0               0
#
#    Facebook_Shared  Income  Education_Score   Age First_Interaction City_Type  \
# 0                0     1.0             90.0  39.0         18-Jun-03       NaN
# 1                0     1.0              NaN  40.0         20-Jul-03         H
# 2                0     3.0             87.0  46.0         02-Nov-02         D
# 3                0     1.0             75.0  47.0         02-Nov-02         D
# 4                0     3.0              NaN  80.0         24-Nov-02         H
#
#    Employer_Category
# 0  Software Industry
# ...
